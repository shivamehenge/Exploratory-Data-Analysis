# %% [markdown]
# # LetsGrowMore (LGM) - Virtual Internship Program

# %% [markdown]
# # Name - Shiva Dagdu Mehenge

# %% [markdown]
# # Data Science Intern

# %% [markdown]
# # Intermediate Level Task

# %% [markdown]
# # Task - Exploratory Data Analysis on Dataset -Terrorism

# %% [markdown]
# # Imorting Modules

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Read the Data

# %%
df = pd.read_csv('C:\\Users\\Shivv\\Downloads\\globalterrorismdb.data.csv', encoding = 'ISO-8859-1')

# %%
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %% [markdown]
# # Information and Describe

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate         0
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.isna()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False       False     False       False
# 1         False  False   False  False       False     False        True
# 2         False  False   False  False       False     False        True
# 3         False  False   False  False       False     False        True
# 4         False  False   False  False       False     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False       False     False        True
# 181687    False  False   False  False       False     False        True
# 181688    False  False   False  False       False     False        True
# 181689    False  False   False  False       False     False        True
# 181690    False  False   False  False       False     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# ...

# %%
value = df['related']
value = value.fillna(value.mode(), inplace = True)

# %%
df.isna()
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False       False     False       False
# 1         False  False   False  False       False     False        True
# 2         False  False   False  False       False     False        True
# 3         False  False   False  False       False     False        True
# 4         False  False   False  False       False     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False       False     False        True
# 181687    False  False   False  False       False     False        True
# 181688    False  False   False  False       False     False        True
# 181689    False  False   False  False       False     False        True
# 181690    False  False   False  False       False     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.keys()
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# # Importing Visualization Modules and Packages

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import math
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Working with Dataset

# %%
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# Rename Columns

# %%
terr_df=df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country',
                               'region_txt':'Region','provstate':'State','city':'City',
                               'attacktype1_txt':'Attack_type','targtype1_txt':'Target_type',
                             'targsubtype1_txt':'Target_subtype','gname':'Gang_name',
                               'weaptype1_txt':'Weapon_type'})

# %%
terr_df
# Out:
#              eventid  Year  Month  Day approxdate  extended resolution  \
# 0       197000000001  1970      7    2        NaN         0        NaN
# 1       197000000002  1970      0    0        NaN         0        NaN
# 2       197001000001  1970      1    0        NaN         0        NaN
# 3       197001000002  1970      1    0        NaN         0        NaN
# 4       197001000003  1970      1    0        NaN         0        NaN
# ...              ...   ...    ...  ...        ...       ...        ...
# 181686  201712310022  2017     12   31        NaN         0        NaN
# 181687  201712310029  2017     12   31        NaN         0        NaN
# 181688  201712310030  2017     12   31        NaN         0        NaN
# 181689  201712310031  2017     12   31        NaN         0        NaN
# 181690  201712310032  2017     12   31        NaN         0        NaN
#
#         country             Country  region  ... addnotes  \
# ...

# %% [markdown]
# Find Null value and Fill it!

# %%
terr_df.isna().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# Day                0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# Fill a Null Values

# %%
terr_df['approxdate'] = terr_df['approxdate'].fillna('others')

# %%
terr_df['relate']=terr_df['related'].fillna('Unknown')

# %%
terr_df['addnotes']=terr_df['addnotes'].fillna('Unknown')

# %%
terr_df['related']=terr_df['related'].fillna('Unknown')

# %%
terr_df.isna().sum()
# Out:
# eventid       0
# Year          0
# Month         0
# Day           0
# approxdate    0
#              ..
# INT_IDEO      0
# INT_MISC      0
# INT_ANY       0
# related       0
# relate        0
# Length: 136, dtype: int64

# %%
terr_df.columns.unique()
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'approxdate', 'extended',
#        'resolution', 'country', 'Country', 'region',
#        ...
#        'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY', 'related', 'relate'],
#       dtype='object', length=136)

# %%
terr_df.nunique()
# Out:
# eventid       181691
# Year              47
# Month             13
# Day               32
# approxdate      2245
#                ...
# INT_IDEO           3
# INT_MISC           3
# INT_ANY            3
# related        14307
# relate         14307
# Length: 136, dtype: int64

# %%
print(terr_df['Region'].unique())
# Out:
# ['Central America & Caribbean' 'North America' 'Southeast Asia'
#  'Western Europe' 'East Asia' 'South America' 'Eastern Europe'
#  'Sub-Saharan Africa' 'Middle East & North Africa' 'Australasia & Oceania'
#  'South Asia' 'Central Asia']

# %%
terr_df['Region'].nunique()
# Out:
# 12

# %%
terr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 136 entries, eventid to relate
# dtypes: float64(55), int64(22), object(59)
# memory usage: 188.5+ MB

# %%
terr_df['Country'].value_counts().head(10)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
terr_df['Region'].value_counts().head(10)
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: Region, dtype: int64

# %%
terr_df['State'].value_counts().head(10)
# Out:
# Baghdad               7645
# Unknown               4711
# Northern Ireland      4498
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: State, dtype: int64

# %%
terr_df['Target_subtype'].value_counts().head(10)
# Out:
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# others                                                     10373
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
# Government Personnel (excluding police, military)           6610
# Village/City/Town/Suburb                                    6542
# Politician or Political Party Movement/Meeting/Rally        6306
# Police Building (headquarters, station, school)             5907
# Military Barracks/Base/Headquarters/Checkpost               5211
# Name: Target_subtype, dtype: int64

# %%
terr_df['City'].value_counts().head(10)
# Out:
# Unknown         10209
# Baghdad          7589
# Karachi          2652
# Lima             2359
# Mosul            2265
# Belfast          2171
# Santiago         1621
# Mogadishu        1581
# San Salvador     1558
# Istanbul         1048
# Name: City, dtype: int64

# %%
terr_df['Attack_type'].value_counts().head(10)
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack_type, dtype: int64

# %%
terr_df['Gang_name'].value_counts().head(10)
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: Gang_name, dtype: int64

# %%
terr_df['Weapon_type'].value_counts().head(5)
# Out:
# Explosives    92426
# Firearms      58524
# Unknown       15157
# Incendiary    11135
# Melee          3655
# Name: Weapon_type, dtype: int64

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(20,5));
sns.countplot(x=terr_df.Weapon_type);

# %%
plt.figure(figsize=(20,5));
plt.xticks(rotation = 90)
plt.title('Attacks by Year')
sns.countplot(x=terr_df.Year);

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Month')
sns.countplot(x=terr_df.Month);

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Day')
sns.countplot(x=terr_df.Day)
# Out:
# <AxesSubplot:title={'center':'Attacks by Day'}, xlabel='Day', ylabel='count'>

# %%
plt.figure(figsize=(30,5));
plt.rcParams.update({'font.size':8});
plt.xticks(rotation = 90)
plt.title('Attacks by Country')
sns.countplot(x=terr_df.Country);

# %% [markdown]
# Thanku!!!
